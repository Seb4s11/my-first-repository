# %% [markdown]
# <a href="https://colab.research.google.com/github/Seb4s11/my-first-repository/blob/main/Diccionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("Piedra, papel o tijera")
play_again = True

while play_again:
    puntos_usuario = 0
    puntos_cpu = 0

    def juegos():
      list = ["piedra", "papel", "tijera"]
      choice_cpu = random.choice(list)
      if choice_cpu == "piedra":
        choice_cpu = 1
      elif choice_cpu == "papel":
        choice_cpu = 2
      else:
        choice_cpu = 3
      return choice_cpu

    def game():
        choice_user = input("piedra, papel o tijera: ")
        choice_user = choice_user.lower()
        if choice_user == "piedra":
            choice_user = 1
        elif choice_user == "papel":
            choice_user = 2
        elif choice_user == "tijera":
            choice_user = 3
        else:
            print("Opcion no valida")
        return choice_user

    cpu_choice = juegos()
    user_choice = game()

    def comparacion(choice_cpu, choice_user):
      print("CPU:", cpu_choice)
      print("Usuario:", user_choice)
      if choice_cpu == choice_user:
        resultado = "Empate"
        print(resultado)
      elif choice_cpu == 1 and choice_user == 2:
        winner = "Usuario"
        resultado = "Ganaste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 1 and choice_user == 3 :
        winner = "CPU"
        resultado = "Perdiste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 2 and choice_user == 1 :
        winner = "CPU"
        resultado = "perdiste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 2 and choice_user == 3 :
        winner = "Usuario"
        resultado = "Ganaste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 3 and choice_user == 1 :
        winner = "Usuario"
        resultado = "Ganaste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 3 and choice_user == 2 :
        winner = "CPU"
        resultado = "Perdiste"
        print("El ganador fue el", winner, ":", resultado)
      else:
        print("Opcion no valida")
      return winner

    comparacion(cpu_choice, user_choice)

    def puntos():
        global puntos_usuario, puntos_cpu  # Declare puntos_usuario and puntos_cpu as global
        winner = comparacion(cpu_choice, user_choice)
        if winner == "Usuario":
            puntos_usuario += 1
        elif winner == "Empate":
            puntos_usuario += 0
            puntos_cpu += 0
        elif winner == "CPU":
            puntos_cpu += 1
        else:
            print("Opcion no valida")
        return puntos_usuario, puntos_cpu

    puntos()
    print(f"\n Tienes {puntos_usuario} Y la CPU tiene {puntos_cpu}")

    respuesta = input("¿Quieres jugar de nuevo? (SI/NO):  ").lower()
    if respuesta != "si":
        play_again = False
# Out:
# Piedra, papel o tijera
# piedra, papel o tijera: papel
# CPU: 2
# Usuario: 2
# Empate
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-35-4e506a383db0> in <cell line: 0>()
#      69       return winner
#      70
# ---> 71     comparacion(cpu_choice, user_choice)
#      72
#      73     def puntos():
#
# <ipython-input-35-4e506a383db0> in comparacion(choice_cpu, choice_user)
#      67       else:
#      68         print("Opcion no valida")
# ---> 69       return winner
#      70
#      71     comparacion(cpu_choice, user_choice)
#
# UnboundLocalError: cannot access local variable 'winner' where it is not associated with a value

# %%
import random

print("Piedra, papel o tijera")
play_again = True

while play_again:
    puntos_usuario = 0
    puntos_cpu = 0

    def juegos():
      list = ["piedra", "papel", "tijera"]
      choice_cpu = random.choice(list)
      if choice_cpu == "piedra":
        choice_cpu = 1
      elif choice_cpu == "papel":
        choice_cpu = 2
      else:
        choice_cpu = 3
      return choice_cpu

    def game():
        choice_user = input("piedra, papel o tijera: ")
        choice_user = choice_user.lower()
        if choice_user == "piedra":
            choice_user = 1
        elif choice_user == "papel":
            choice_user = 2
        elif choice_user == "tijera":
            choice_user = 3
        else:
            print("Opcion no valida")
            # Return None to indicate invalid input
            return None
        return choice_user

    cpu_choice = juegos()
    user_choice = game()

    def comparacion(choice_cpu, choice_user):
      print("CPU:", cpu_choice)
      print("Usuario:", user_choice)
      # Initialize winner to None
      winner = None
      if choice_cpu == choice_user:
        resultado = "Empate"
        print(resultado)
        winner = "Empate"  # Assign 'Empate' to winner in case of a tie
      elif choice_cpu == 1 and choice_user == 2:
        winner = "Usuario"
        resultado = "Ganaste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 1 and choice_user == 3 :
        winner = "CPU"
        resultado = "Perdiste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 2 and choice_user == 1 :
        winner = "CPU"
        resultado = "perdiste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 2 and choice_user == 3 :
        winner = "Usuario"
        resultado = "Ganaste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 3 and choice_user == 1 :
        winner = "Usuario"
        resultado = "Ganaste"
        print("El ganador fue el", winner, ":", resultado)
      elif choice_cpu == 3 and choice_user == 2 :
        winner = "CPU"
        resultado = "Perdiste"
        print("El ganador fue el", winner, ":", resultado)
      else:
        print("Opcion no valida")
      return winner # Now winner will always have a value to return

    comparacion(cpu_choice, user_choice)

    def puntos():
        global puntos_usuario, puntos_cpu  # Declare puntos_usuario and puntos_cpu as global
        winner = comparacion(cpu_choice, user_choice)
        if winner == "Usuario":
            puntos_usuario += 1
        elif winner == "Empate":
            puntos_usuario += 0
            puntos_cpu += 0
        elif winner == "CPU":
            puntos_cpu += 1
        else:
            print("Opcion no valida")
        return puntos_usuario, puntos_cpu

    puntos()
    print(f"\n Tienes {puntos_usuario} Y la CPU tiene {puntos_cpu}")

    respuesta = input("¿Quieres jugar de nuevo? (SI/NO):  ").lower()
    if respuesta != "si":
        play_again = False
# Out:
# Piedra, papel o tijera
# piedra, papel o tijera: PIEDRA
# CPU: 1
# Usuario: 1
# Empate
# CPU: 1
# Usuario: 1
# Empate
#
#  Tienes 0 Y la CPU tiene 0
# ¿Quieres jugar de nuevo? (SI/NO):  NO

# %%
import random

def juegos():
  choice_cpu = random.choice(range(1,4))
  if choice_cpu == 1:
    choice_cpu = "piedra"
  elif choice_cpu == 2:
    choice_cpu = "papel"
  else:
    choice_cpu = "tijera"
  return choice_cpu

def game():
    choice_user_input = input("piedra, papel o tijeras: ")
    choice_user_input = choice_user_input.lower()
    if choice_user_input == "piedra":
          choice_user = "piedra"
    elif choice_user_input == "papel":
          choice_user = "papel"
    elif choice_user_input == "tijera":
          choice_user = "tijera"
    else:
        print("Opcion no valida")
    return choice_user

choice_cpu=juegos()
choice_user=game()

print("Computadora: ", choice_cpu)
if choice_cpu == choice_user:
  print("Empate")
elif choice_cpu == "piedra" and choice_user == "papel":
  print("Ganaste")
elif choice_cpu == "papel" and choice_user == "tijera":
  print("Perdiste")
elif choice_cpu == "papel" and choice_user == "piedra":
  print("Perdiste")
elif choice_cpu == "papel" and choice_user == "tijera":
  print("Ganaste")
elif choice_cpu == "tijera" and choice_user == "piedra":
  print("Ganaste")
elif choice_cpu == "tijera" and choice_user == "papel":
  print("Perdiste")
else:
  print("Opcion no valida")

# %%
def continue_game(user_choice):
    if user_choice.upper() in ('Y', 'N'):
        if user_choice.upper() == 'Y':
            return True
    return False

def start_game():
    print("Welcome to Rock, Paper, Scissors")
    user_choice = input("Would you like to play? (Y/N) ")
    return continue_game(user_choice)

def terminate_game():
    user_choice = input("Would you like to play again? (Y/N) ")
    return continue_game(user_choice)

def show_game_status(current_round, user_points, computer_points, current_winner):
    print(f"\nCurrent round: {current_round}")
    print(f"User Points: {user_points}")
    print(f"Computer Points: {computer_points}")
    print(f"Current Winner: {current_winner}\n")

def advance_round(current_round):
    return current_round + 1

def play_game():
    game_status = start_game()
    current_round = 0
    user_points = 0
    computer_points = 0
    current_winner = "---"
    while game_status:
        current_round = advance_round(current_round)
        show_game_status(current_round, user_points, computer_points, current_winner)
        game_status = terminate_game()



if _name_ == "_main_":
    play_game()
